# %%
import pandas as pd

# %%
column_names = ['index', 'heating_energy', 'cooling_energy', 'country', 'total_energy', 'region']
df = pd.read_csv('heating_and_cooling.csv', delimiter = ','
            , names = column_names)
df
# Out:
#       index  heating_energy  cooling_energy country  total_energy region
# 0         0        70181.07          571.60     USA      70752.67      D
# 1         1        79545.25          527.97     USA      80073.22      P
# 2         2         5796.05        20486.48     USA      26282.53      Y
# 3         3         8239.55        10069.80     ITA      18309.35      I
# 4         4        86888.04         7211.27     USA      94099.31      P
# 5         5        60645.48         5092.15     USA      65737.63      L
# 6         6         6318.99        23734.37     USA      30053.36      T
# 7         7        15491.76        12375.79     USA      27867.55      T
# 8         8        60137.17         4395.16     USA      64532.33      B
# 9         9         1612.05        23093.72     CHN      24705.77      C
# 10       10        49582.35         7640.32     USA      57222.67      R
# 11       11         2525.96         6924.59     USA       9450.55      Y
# ...

# %%
df = df.sort_values(['region'])
df
# Out:
#       index  heating_energy  cooling_energy country  total_energy region
# 2252   2252        13465.54        18573.33     CHN      32038.87      A
# 1510   1510        23007.55        17184.53     USA      40192.08      A
# 1022   1022        37789.99         8291.95     USA      46081.94      A
# 137     137         2869.61        15894.09     BRA      18763.70      A
# 2254   2254        46326.85         8915.70     USA      55242.55      A
# 755     755        25350.83         1473.03     USA      26823.86      A
# 1479   1479            0.46        21436.59     BRA      21437.05      A
# 2242   2242        67524.60         7771.53     USA      75296.13      A
# 2959   2959        20032.61        13837.23     USA      33869.84      A
# 1462   1462        56150.92         5427.10     USA      61578.02      A
# 763     763            5.90        26473.53     BRA      26479.43      A
# 2856   2856            0.00        44914.07     BRA      44914.07      A
# ...

# %%
df.groupby(['region'], as_index=False)['total_energy'].max()
# Out:
#    region  total_energy
# 0       A     160354.30
# 1       B     254308.05
# 2       C     216541.27
# 3       D     178143.34
# 4       E     167186.17
# 5       F     125968.11
# 6       G     169188.77
# 7       H     165984.91
# 8       I     168771.93
# 9       J     193405.70
# 10      K     201819.15
# 11      L     274345.72
# 12      M     150731.22
# 13      N     282275.74
# 14      O     170860.86
# 15      P     247590.13
# 16      Q     166772.25
# 17      R     193755.47
# 18      S     149645.36
# 19      T     242814.85
# 20      U     324698.73
# 21      V     195075.09
# 22      W     152885.65
# 23      X     186737.68
# 24      Y     184367.89
# 25      Z     151450.94

# %%
df.groupby(['region'])['total_energy'].max()
# Out:
# region
# A    160354.30
# B    254308.05
# C    216541.27
# D    178143.34
# E    167186.17
# F    125968.11
# G    169188.77
# H    165984.91
# I    168771.93
# J    193405.70
# K    201819.15
# L    274345.72
# M    150731.22
# N    282275.74
# O    170860.86
# P    247590.13
# Q    166772.25
# R    193755.47
# S    149645.36
# T    242814.85
# U    324698.73
# V    195075.09
# W    152885.65
# X    186737.68
# Y    184367.89
# Z    151450.94
# Name: total_energy, dtype: float64

# %%
df.groupby(['region'], as_index=False)['total_energy'].max()
# Out:
#    region  total_energy
# 0       A     160354.30
# 1       B     254308.05
# 2       C     216541.27
# 3       D     178143.34
# 4       E     167186.17
# 5       F     125968.11
# 6       G     169188.77
# 7       H     165984.91
# 8       I     168771.93
# 9       J     193405.70
# 10      K     201819.15
# 11      L     274345.72
# 12      M     150731.22
# 13      N     282275.74
# 14      O     170860.86
# 15      P     247590.13
# 16      Q     166772.25
# 17      R     193755.47
# 18      S     149645.36
# 19      T     242814.85
# 20      U     324698.73
# 21      V     195075.09
# 22      W     152885.65
# 23      X     186737.68
# 24      Y     184367.89
# 25      Z     151450.94
